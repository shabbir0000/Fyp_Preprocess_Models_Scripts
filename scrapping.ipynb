# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install xlsxwriter

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter

# Read URLs from a text file
with open('links.txt', 'r') as file:
    urls = file.read().splitlines()

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'poetry8.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Initialize row number
row_num = 0

# Loop through each URL
for url in urls:
    # Fetch HTML content
    response = requests.get(url)
    if response.status_code == 200:
        html_content = response.text
        print(f'Successfully fetched content from: {url}')
    else:
        print(f'Failed to fetch HTML content for URL: {url}')
        continue

    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find all elements with the CSS class 'has-text-align-right'
    elements_with_right_class = soup.find_all(class_='has-text-align-center')

    # Find elements with the CSS class 'entry-title'
    elements_with_title_class = soup.find_all(class_='entry-title')

    # Extract data from each element and concatenate it into a single string
    text_right_class = '\n'.join([element.get_text() for element in elements_with_right_class])
    text_title_class = '\n'.join([element.get_text() for element in elements_with_title_class])

    # Write the concatenated text to the worksheet in a single cell
    worksheet.write(row_num, 0, text_right_class)
    worksheet.write(row_num, 1, text_title_class)
    row_num += 1

# Close the workbook
workbook.close()

print(f'Scraped content with "has-text-align-right" class saved to {excel_file_path}')
# Out:
# Successfully fetched content from: https://bhulekhatv.com/poetry/15824
# Successfully fetched content from: https://bhulekhatv.com/poetry/15822
# Successfully fetched content from: https://bhulekhatv.com/poetry/15818
# Successfully fetched content from: https://bhulekhatv.com/poetry/15799
# Successfully fetched content from: https://bhulekhatv.com/poetry/15796
# Successfully fetched content from: https://bhulekhatv.com/poetry/15794
# Successfully fetched content from: https://bhulekhatv.com/poetry/15792
# Successfully fetched content from: https://bhulekhatv.com/poetry/15790
# Successfully fetched content from: https://bhulekhatv.com/poetry/15788
# Successfully fetched content from: https://bhulekhatv.com/poetry/15780
# Successfully fetched content from: https://bhulekhatv.com/poetry/15759
# Successfully fetched content from: https://bhulekhatv.com/poetry/15757
# Successfully fetched content from: https://bhulekhatv.com/poetry/15755
# ...

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter

# URL to scrape data from
url = 'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1'

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'salesforce_listing_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Initialize row number
row_num = 0

# Fetch HTML content from the provided URL
response = requests.get(url)
if response.status_code == 200:
    html_content = response.text
    print(f'Successfully fetched content from: {url}')
else:
    print(f'Failed to fetch HTML content for URL: {url}')
    exit()

# Parse HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find the specific <h1> tag with type-style="display-6"
h1_tag = soup.find('h1', {'type-style': 'display-6'})

# Find the specific <p> tag with type-style="body-3"
p_tag = soup.find('p', {'type-style': 'body-3'})

# Print and check if the tags were found
if h1_tag:
    print(f"Found <h1> tag: {h1_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'h1')
    worksheet.write(row_num, 1, h1_tag.get_text().strip())
    row_num += 1
else:
    print("No <h1> tag with type-style='display-6' found")

if p_tag:
    print(f"Found <p> tag: {p_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'p')
    worksheet.write(row_num, 1, p_tag.get_text().strip())
    row_num += 1
else:
    print("No <p> tag with type-style='body-3' found")

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1
# No <h1> tag with type-style='display-6' found
# No <p> tag with type-style='body-3' found
# Scraped content saved to salesforce_listing_data.xlsx

# %%
# !apt-get update
# !apt-get install -y chromium-browser
# !apt-get install -y chromium-chromedriver
# !pip install selenium

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode (no GUI)
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")

# Create a webdriver instance for Chrome
driver = webdriver.Chrome(service=Service('/usr/bin/chromedriver'), options=chrome_options)

# URL to scrape
url = 'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1'

# Open the URL with Selenium
driver.get(url)

# Give the page time to load
time.sleep(5)  # Adjust based on your network speed

# Get the HTML content after the JavaScript is executed
html_content = driver.page_source

# Close the browser after fetching the content
driver.quit()

# Print the raw HTML content for debugging
print(html_content)
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Ign:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter
import time

# URL to scrape data from
url = 'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1'

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'salesforce_listing_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Initialize row number
row_num = 0

# Fetch HTML content from the provided URL
response = requests.get(url)
if response.status_code == 200:
    # Add a 10-second delay to ensure the page has loaded completely
    print(f'Successfully fetched content from: {url}')
    print('Waiting for 10 seconds...')
    time.sleep(10)  # Delay for 10 seconds
    html_content = response.text
else:
    print(f'Failed to fetch HTML content for URL: {url}')
    exit()

# Parse HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find the specific <h1> tag with type-style="display-6"
h1_tag = soup.find('h1', {'type-style': 'display-6'})

# Find the specific <p> tag with type-style="body-3"
p_tag = soup.find('p', {'type-style': 'body-3'})

# Print and check if the tags were found
if h1_tag:
    print(f"Found <h1> tag: {h1_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'h1')
    worksheet.write(row_num, 1, h1_tag.get_text().strip())
    row_num += 1
else:
    print("No <h1> tag with type-style='display-6' found")

if p_tag:
    print(f"Found <p> tag: {p_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'p')
    worksheet.write(row_num, 1, p_tag.get_text().strip())
    row_num += 1
else:
    print("No <p> tag with type-style='body-3' found")

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1
# Waiting for 10 seconds...
# No <h1> tag with type-style='display-6' found
# No <p> tag with type-style='body-3' found
# Scraped content saved to salesforce_listing_data.xlsx

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter
import time

# URL to scrape data from
url = 'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1'

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'salesforce_listing_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Initialize row number
row_num = 0

# Fetch HTML content from the provided URL
response = requests.get(url)
if response.status_code == 200:
    # Add a 10-second delay to ensure the page has loaded completely
    print(f'Successfully fetched content from: {url}')
    print('Waiting for 10 seconds...')
    time.sleep(10)  # Delay for 10 seconds
    html_content = response.text
else:
    print(f'Failed to fetch HTML content for URL: {url}')
    exit()

# Parse HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find the <title> tag
title_tag = soup.find('title')

# Find the specific <h1> tag with type-style="display-6"
h1_tag = soup.find('h1', {'type-style': 'display-6'})

# Find the specific <p> tag with type-style="body-3"
p_tag = soup.find('p', {'type-style': 'body-3'})

# Print and check if the tags were found
if title_tag:
    print(f"Found <title> tag: {title_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'title')
    worksheet.write(row_num, 1, title_tag.get_text().strip())
    row_num += 1
else:
    print("No <title> tag found")

if h1_tag:
    print(f"Found <h1> tag: {h1_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'h1')
    worksheet.write(row_num, 1, h1_tag.get_text().strip())
    row_num += 1
else:
    print("No <h1> tag with type-style='display-6' found")

if p_tag:
    print(f"Found <p> tag: {p_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'p')
    worksheet.write(row_num, 1, p_tag.get_text().strip())
    row_num += 1
else:
    print("No <p> tag with type-style='body-3' found")

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1
# Waiting for 10 seconds...
# Found <title> tag: Survey Vista : 100% Native Salesforce Surveys, Forms, Quizzes, and Checklists
# No <h1> tag with type-style='display-6' found
# No <p> tag with type-style='body-3' found
# Scraped content saved to salesforce_listing_data.xlsx

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter
import time

# URL to scrape data from
url = 'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1'

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'salesforce_listing_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Initialize row number
row_num = 0

# Fetch HTML content from the provided URL
response = requests.get(url)
if response.status_code == 200:
    # Add a 10-second delay to ensure the page has loaded completely
    print(f'Successfully fetched content from: {url}')
    print('Waiting for 10 seconds...')
    time.sleep(10)  # Delay for 10 seconds
    html_content = response.text
else:
    print(f'Failed to fetch HTML content for URL: {url}')
    exit()

# Parse HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find the <title> tag
title_tag = soup.find('title')

# Find the specific <h1> tag with type-style="display-6"
h1_tag = soup.find('h1', {'type-style': 'display-6'})

# Find the specific <p> tag with type-style="body-3"
p_tag = soup.find('p', {'type-style': 'body-3'})

# Print and check if the tags were found
if title_tag:
    print(f"Found <title> tag: {title_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'title')
    worksheet.write(row_num, 1, title_tag.get_text().strip())
    row_num += 1
else:
    print("No <title> tag found")

if h1_tag:
    print(f"Found <h1> tag: {h1_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'h1')
    worksheet.write(row_num, 1, h1_tag.get_text().strip())
    row_num += 1
else:
    print("No <h1> tag with type-style='display-6' found")

if p_tag:
    print(f"Found <p> tag: {p_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'p')
    worksheet.write(row_num, 1, p_tag.get_text().strip())
    row_num += 1
else:
    print("No <p> tag with type-style='body-3' found")

# Find all <script> tags and print their content
script_tags = soup.find_all('script')
if script_tags:
    for script in script_tags:
        script_content = script.string.strip() if script.string else "No content"
        print(f"Found <script> tag: {script_content}")
        worksheet.write(row_num, 0, 'script')
        worksheet.write(row_num, 1, script_content)
        row_num += 1
else:
    print("No <script> tags found")

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1
# Waiting for 10 seconds...
# Found <title> tag: Survey Vista : 100% Native Salesforce Surveys, Forms, Quizzes, and Checklists
# No <h1> tag with type-style='display-6' found
# No <p> tag with type-style='body-3' found
# Found <script> tag: (function (w, d, s, l, i) {
#                 w[l] = w[l] || [];
#                 w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' });
#                 var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s),
#                     dl = l != 'dataLayer' ? '&l=' + l : '';
#                 j.async = true;
#                 j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#                 f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-WH23RMD');
# Found <script> tag: [
# ...

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter
import time
import re

# URL to scrape data from
url = 'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1'

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'salesforce_listing_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Initialize row number
row_num = 0

# Fetch HTML content from the provided URL
response = requests.get(url)
if response.status_code == 200:
    # Add a 10-second delay to ensure the page has loaded completely
    print(f'Successfully fetched content from: {url}')
    print('Waiting for 10 seconds...')
    time.sleep(10)  # Delay for 10 seconds
    html_content = response.text
else:
    print(f'Failed to fetch HTML content for URL: {url}')
    exit()

# Parse HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find the <title> tag
title_tag = soup.find('title')

# Find the specific <h1> tag with type-style="display-6"
h1_tag = soup.find('h1', {'type-style': 'display-6'})

# Find the specific <p> tag with type-style="body-3"
p_tag = soup.find('p', {'type-style': 'body-3'})

# Print and check if the tags were found
if title_tag:
    print(f"Found <title> tag: {title_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'title')
    worksheet.write(row_num, 1, title_tag.get_text().strip())
    row_num += 1
else:
    print("No <title> tag found")

if h1_tag:
    print(f"Found <h1> tag: {h1_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'h1')
    worksheet.write(row_num, 1, h1_tag.get_text().strip())
    row_num += 1
else:
    print("No <h1> tag with type-style='display-6' found")

if p_tag:
    print(f"Found <p> tag: {p_tag.get_text().strip()}")
    worksheet.write(row_num, 0, 'p')
    worksheet.write(row_num, 1, p_tag.get_text().strip())
    row_num += 1
else:
    print("No <p> tag with type-style='body-3' found")

# Find all <script> tags and look for window.stores
script_tags = soup.find_all('script')
stores_data = None  # Initialize variable to hold stores data

for script in script_tags:
    # Check if the script has any content
    if script.string:
        # Use regex to find the window.stores variable
        match = re.search(r'window\.stores\s*=\s*(.*?);', script.string, re.DOTALL)
        if match:
            stores_data = match.group(1).strip()  # Get the matched stores data
            print(f"Found window.stores: {stores_data}")
            worksheet.write(row_num, 0, 'window.stores')
            worksheet.write(row_num, 1, stores_data)
            row_num += 1
            break  # Stop searching after finding the first occurrence

if not stores_data:
    print("No window.stores found in <script> tags")

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1
# Waiting for 10 seconds...
# Found <title> tag: Survey Vista : 100% Native Salesforce Surveys, Forms, Quizzes, and Checklists
# No <h1> tag with type-style='display-6' found
# No <p> tag with type-style='body-3' found
# ...

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter
import time
import re
import json

# URL to scrape data from
url = 'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1'

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'salesforce_listing_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Initialize row number
row_num = 0

# Fetch HTML content from the provided URL
response = requests.get(url)
if response.status_code == 200:
    # Add a 10-second delay to ensure the page has loaded completely
    print(f'Successfully fetched content from: {url}')
    print('Waiting for 10 seconds...')
    time.sleep(10)  # Delay for 10 seconds
    html_content = response.text
else:
    print(f'Failed to fetch HTML content for URL: {url}')
    exit()

# Parse HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find all <script> tags and look for window.stores
script_tags = soup.find_all('script')
stores_data = None  # Initialize variable to hold stores data

for script in script_tags:
    # Check if the script has any content
    if script.string:
        # Use regex to find the window.stores variable
        match = re.search(r'window\.stores\s*=\s*(.*?);', script.string, re.DOTALL)
        if match:
            stores_data = match.group(1).strip()  # Get the matched stores data
            print(f"Found window.stores: {stores_data}")

            # Try to parse the JSON data to extract the listing object
            try:
                stores_json = json.loads(stores_data)
                if 'LISTING' in stores_json:
                    listing_data = stores_json['LISTING']
                    print(f"Found listing: {json.dumps(listing_data, indent=4)}")

                    # Write the listing object to Excel
                    worksheet.write(row_num, 0, 'LISTING')
                    worksheet.write(row_num, 1, json.dumps(listing_data))  # Store it as a JSON string
                    row_num += 1

                    # If you want to format the listing data further, you can iterate through its keys
                    for key, value in listing_data.items():
                        if isinstance(value, list):
                            # For lists, we can write them as strings
                            worksheet.write(row_num, 0, key)
                            worksheet.write(row_num, 1, json.dumps(value))  # Convert list to JSON string
                        elif isinstance(value, dict):
                            # For nested dictionaries, you can do the same
                            worksheet.write(row_num, 0, key)
                            worksheet.write(row_num, 1, json.dumps(value))  # Convert dict to JSON string
                        else:
                            worksheet.write(row_num, 0, key)
                            worksheet.write(row_num, 1, value)
                        row_num += 1
                else:
                    print("No listing object found in window.stores")
            except json.JSONDecodeError:
                print("Error decoding JSON from window.stores")

            break  # Stop searching after finding the first occurrence

if not stores_data:
    print("No window.stores found in <script> tags")

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1
# Waiting for 10 seconds...
# ...

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter
import time
import re
import json

# URL to scrape data from
url = 'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1'

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'salesforce_listing_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Initialize row number
row_num = 0

# Fetch HTML content from the provided URL
response = requests.get(url)
if response.status_code == 200:
    # Add a 10-second delay to ensure the page has loaded completely
    print(f'Successfully fetched content from: {url}')
    print('Waiting for 10 seconds...')
    time.sleep(10)  # Delay for 10 seconds
    html_content = response.text
else:
    print(f'Failed to fetch HTML content for URL: {url}')
    exit()

# Parse HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find all <script> tags and look for window.stores
script_tags = soup.find_all('script')
stores_data = None  # Initialize variable to hold stores data

for script in script_tags:
    # Check if the script has any content
    if script.string:
        # Use regex to find the window.stores variable
        match = re.search(r'window\.stores\s*=\s*(.*?);', script.string, re.DOTALL)
        if match:
            stores_data = match.group(1).strip()  # Get the matched stores data
            print(f"Found window.stores: {stores_data}")

            # Try to parse the JSON data to extract the listing object
            try:
                stores_json = json.loads(stores_data)
                if 'LISTING' in stores_json:
                    listing_data = stores_json['LISTING']
                    # print(f"Found listing: {json.dumps(listing_data, indent=4)}")

                    # Extract the publisher object
                    publisher_data = listing_data.get('listing', {})  # Extract publisher directly
                    if publisher_data:
                        # Print the publisher object
                        publisher_data1 = publisher_data.get('publisher', {})
                        # print(f"listing Publisher Object: {json.dumps(publisher_data1, indent=4)}")
                        name = publisher_data1.get('name', 'Not found')
                        email = publisher_data1.get('email', 'Not found')
                        active = publisher_data1.get('active', 'Not found')
                        country = publisher_data1.get('country', 'Not found')
                        website = publisher_data1.get('website', 'Not found')

                        title = publisher_data.get('title', 'Not found')
                        # Print extracted fields
                        print(f"Publisher Name: {name}")
                        print(f"Publisher Email: {email}")
                        print(f"Detail Page Link: {url}")
                        print(f"Publisher Country: {country}")
                        print(f"Publisher website: {website}")
                        print(f"Publisher Title: {title}")
                        # Write the publisher object to Excel
                        worksheet.write(row_num, 0, 'publisher')
                        worksheet.write(row_num, 1, json.dumps(publisher_data))  # Store it as a JSON string
                        row_num += 1
                    else:
                        print("No publisher object found in the listing")

                else:
                    print("No listing object found in window.stores")
            except json.JSONDecodeError:
                print("Error decoding JSON from window.stores")

            break  # Stop searching after finding the first occurrence

if not stores_data:
    print("No window.stores found in <script> tags")

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1
# Waiting for 10 seconds...
# ...

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter
import time
import re
import json

# URL to scrape data from
url = 'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1'

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'salesforce_listing_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Write headers to the Excel sheet
headers = ['Publisher Name', 'Publisher Email', 'Detail Page Link', 'Publisher Country', 'Publisher Website', 'Publisher Title']
for col_num, header in enumerate(headers):
    worksheet.write(0, col_num, header)  # Write headers in the first row

# Initialize row number for data entry
row_num = 1

# Fetch HTML content from the provided URL
response = requests.get(url)
if response.status_code == 200:
    # Add a 10-second delay to ensure the page has loaded completely
    print(f'Successfully fetched content from: {url}')
    print('Waiting for 10 seconds...')
    time.sleep(10)  # Delay for 10 seconds
    html_content = response.text
else:
    print(f'Failed to fetch HTML content for URL: {url}')
    exit()

# Parse HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find all <script> tags and look for window.stores
script_tags = soup.find_all('script')
stores_data = None  # Initialize variable to hold stores data

for script in script_tags:
    # Check if the script has any content
    if script.string:
        # Use regex to find the window.stores variable
        match = re.search(r'window\.stores\s*=\s*(.*?);', script.string, re.DOTALL)
        if match:
            stores_data = match.group(1).strip()  # Get the matched stores data
            print(f"Found window.stores: {stores_data}")

            # Try to parse the JSON data to extract the listing object
            try:
                stores_json = json.loads(stores_data)
                if 'LISTING' in stores_json:
                    listing_data = stores_json['LISTING']

                    # Extract the publisher object
                    publisher_data = listing_data.get('listing', {})  # Extract publisher directly
                    if publisher_data:
                        # Extract details from the publisher object
                        publisher_data1 = publisher_data.get('publisher', {})
                        name = publisher_data1.get('name', 'Not found')
                        email = publisher_data1.get('email', 'Not found')
                        country = publisher_data1.get('country', 'Not found')
                        website = publisher_data1.get('website', 'Not found')
                        title = publisher_data.get('title', 'Not found')

                        # Print extracted fields
                        print(f"Publisher Name: {name}")
                        print(f"Publisher Email: {email}")
                        print(f"Detail Page Link: {url}")
                        print(f"Publisher Country: {country}")
                        print(f"Publisher Website: {website}")
                        print(f"Publisher Title: {title}")

                        # Write the publisher details to Excel
                        worksheet.write(row_num, 0, name)      # Publisher Name
                        worksheet.write(row_num, 1, email)     # Publisher Email
                        worksheet.write(row_num, 2, url)       # Detail Page Link
                        worksheet.write(row_num, 3, country)    # Publisher Country
                        worksheet.write(row_num, 4, website)   # Publisher Website
                        worksheet.write(row_num, 5, title)     # Publisher Title
                        row_num += 1
                    else:
                        print("No publisher object found in the listing")

                else:
                    print("No listing object found in window.stores")
            except json.JSONDecodeError:
                print("Error decoding JSON from window.stores")

            break  # Stop searching after finding the first occurrence

if not stores_data:
    print("No window.stores found in <script> tags")

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1
# Waiting for 10 seconds...
# ...

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter
import time
import re
import json

# List of URLs to scrape data from
urls = [
    'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1',
    'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000EX3qVUAT',
    'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3000000B4lIxEAJ',
    'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3000000DylJTEAZ',
    'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3000000B3LePEAV',
    'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N4V00000JTeWyUAL',
    'https://appexchange.salesforce.com/appxListingDetail?listingId=a0N30000003ICFYEA4',
    # Add more URLs here
    # 'https://appexchange.salesforce.com/appxListingDetail?listingId=anotherId',
]

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'salesforce_listing_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Write headers to the Excel sheet
headers = ['Publisher Name', 'Publisher Email', 'Detail Page Link', 'Publisher Country', 'Publisher Website', 'Publisher Title']
for col_num, header in enumerate(headers):
    worksheet.write(0, col_num, header)  # Write headers in the first row

# Initialize row number for data entry
row_num = 1

# Loop through each URL
for url in urls:
    # Fetch HTML content from the provided URL
    response = requests.get(url)
    if response.status_code == 200:
        # Add a delay to ensure the page has loaded completely
        print(f'Successfully fetched content from: {url}')
        time.sleep(5)  # Delay for 5 seconds
        html_content = response.text
    else:
        print(f'Failed to fetch HTML content for URL: {url}')
        continue  # Skip to the next URL

    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find all <script> tags and look for window.stores
    script_tags = soup.find_all('script')
    stores_data = None  # Initialize variable to hold stores data

    for script in script_tags:
        # Check if the script has any content
        if script.string:
            # Use regex to find the window.stores variable
            match = re.search(r'window\.stores\s*=\s*(.*?);', script.string, re.DOTALL)
            if match:
                stores_data = match.group(1).strip()  # Get the matched stores data
                print(f"Found window.stores: {stores_data}")

                # Try to parse the JSON data to extract the listing object
                try:
                    stores_json = json.loads(stores_data)
                    if 'LISTING' in stores_json:
                        listing_data = stores_json['LISTING']

                        # Extract the publisher object
                        publisher_data = listing_data.get('listing', {})  # Extract publisher directly
                        if publisher_data:
                            # Extract details from the publisher object
                            publisher_data1 = publisher_data.get('publisher', {})
                            name = publisher_data1.get('name', 'Not found')
                            email = publisher_data1.get('email', 'Not found')
                            country = publisher_data1.get('country', 'Not found')
                            website = publisher_data1.get('website', 'Not found')
                            title = publisher_data.get('title', 'Not found')

                            # Print extracted fields
                            print(f"Publisher Name: {name}")
                            print(f"Publisher Email: {email}")
                            print(f"Detail Page Link: {url}")
                            print(f"Publisher Country: {country}")
                            print(f"Publisher Website: {website}")
                            print(f"Publisher Title: {title}")

                            # Write the publisher details to Excel
                            worksheet.write(row_num, 0, name)      # Publisher Name
                            worksheet.write(row_num, 1, email)     # Publisher Email
                            worksheet.write(row_num, 2, url)       # Detail Page Link
                            worksheet.write(row_num, 3, country)    # Publisher Country
                            worksheet.write(row_num, 4, website)   # Publisher Website
                            worksheet.write(row_num, 5, title)     # Publisher Title
                            row_num += 1
                        else:
                            print("No publisher object found in the listing")

                    else:
                        print("No listing object found in window.stores")
                except json.JSONDecodeError:
                    print("Error decoding JSON from window.stores")

                break  # Stop searching after finding the first occurrence

if not stores_data:
    print("No window.stores found in <script> tags")

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: https://appexchange.salesforce.com/appxListingDetail?listingId=a0N3A00000FYkISUA1
# ...

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter

# Read URLs from a text file
with open('links.txt', 'r') as file:
    urls = file.read().splitlines()

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'poetry8.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Write column headers
worksheet.write(0, 0, 'Name')
worksheet.write(0, 1, 'Email')
worksheet.write(0, 2, 'Research Area')

# Initialize row number for data entry, starting from row 1 as row 0 has headers
row_num = 1

# Loop through each URL
for url in urls:
    # Fetch HTML content
    response = requests.get(url)
    if response.status_code == 200:
        html_content = response.text
        print(f'Successfully fetched content from: {url}')
    else:
        print(f'Failed to fetch HTML content for URL: {url}')
        continue

    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract Name
    name_div = soup.find('div', class_='people-info col-md-4 col-sm-12', text=lambda t: t and 'Name:' in t)
    name = name_div.find('h5', id='xm').get_text() if name_div else 'N/A'

    # Extract Email
    email_div = soup.find('div', class_='people-info col-md-4 col-sm-12', text=lambda t: t and 'E-Mail:' in t)
    email = email_div.find('h5', id='dzyj').get_text() if email_div else 'N/A'

    # Extract Research Area
    research_area_div = soup.find('div', class_='col-md-4 col-sm-12')
    research_area_spans = research_area_div.find_all('span', style="line-height: normal") if research_area_div else []
    research_area = ' '.join([span.get_text() for span in research_area_spans])

    # Write data to the worksheet
    worksheet.write(row_num, 0, name)
    worksheet.write(row_num, 1, email)
    worksheet.write(row_num, 2, research_area)

    # Increment row number
    row_num += 1

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter

# Define URLs as an array (list)
urls = [
    "http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339063.html"
    # Add more URLs as needed
]

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'extracted_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Write column headers
worksheet.write(0, 0, 'Name')
worksheet.write(0, 1, 'Email')
worksheet.write(0, 2, 'Research Area')

# Initialize row number for data entry, starting from row 1 as row 0 has headers
row_num = 1

# Loop through each URL
for url in urls:
    try:
        # Fetch HTML content
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        html_content = response.text
        print(f'Successfully fetched content from: {url}')
    except requests.exceptions.RequestException as e:
        print(f'Failed to fetch HTML content for URL: {url} due to {e}')
        continue

    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract Name
    name_div = soup.find('div', class_='people-info col-md-4 col-sm-12', string="Name:")
    name = name_div.find_next('h5').get_text() if name_div else 'N/A'

    # Extract Email
    email_div = soup.find('div', class_='people-info col-md-4 col-sm-12', string="E-Mail:")
    email = email_div.find_next('h5').get_text() if email_div else 'N/A'

    # Extract Research Area
    research_area_spans = soup.select('div span[style="line-height: normal"]')
    research_area = ' '.join([span.get_text() for span in research_area_spans]) if research_area_spans else 'N/A'

    # Write data to the worksheet
    worksheet.write(row_num, 0, name)
    worksheet.write(row_num, 1, email)
    worksheet.write(row_num, 2, research_area)

    # Increment row number
    row_num += 1

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339063.html
# Scraped content saved to extracted_data.xlsx

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter

# Define URLs as an array (list)
urls = [
    "http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339064.html",
    "http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339063.html",
    "http://english.cnic.cas.cn/sourcedb/People/201803/t20180307_339052.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678885.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678886.html",
    "http://english.cnic.cas.cn/sourcedb/People/202001/t20200116_339062.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678887.html",
    "http://english.cnic.cas.cn/sourcedb/People/201803/t20180307_339061.html",
    "http://english.cnic.cas.cn/sourcedb/People/200909/t20090917_339059.html",
    "http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339058.html",
    "http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339057.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678897.html",
    "http://english.cnic.cas.cn/sourcedb/People/201601/t20160111_339056.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678888.html",
    "http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339055.html",
    "http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339054.html",
    "http://english.cnic.cas.cn/sourcedb/People/201505/t20150508_339053.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678891.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678893.html",
    "http://english.cnic.cas.cn/sourcedb/People/201702/t20170213_339051.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678896.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678898.html",
    "http://english.cnic.cas.cn/sourcedb/People/201505/t20150508_339050.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678899.html",
    "http://english.cnic.cas.cn/sourcedb/People/201803/t20180307_339049.html",
    "http://english.cnic.cas.cn/sourcedb/People/201808/t20180828_339048.html",
    "http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339046.html",
    "http://english.cnic.cas.cn/sourcedb/People/201905/t20190515_339045.html",
    "http://english.cnic.cas.cn/sourcedb/People/201305/t20130510_339044.html",
    "http://english.cnic.cas.cn/sourcedb/People/202001/t20200122_339043.html",
    "http://english.cnic.cas.cn/sourcedb/People/202001/t20200122_339042.html",
    "http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339041.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678900.html",
    "http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678901.html",
    "http://english.cnic.cas.cn/sourcedb/People/201803/t20180307_339040.html",
    "http://english.cnic.cas.cn/sourcedb/People/200909/t20090917_339039.html"
]


# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'extracted_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Write column headers
worksheet.write(0, 0, 'Name')
worksheet.write(0, 1, 'Email')
worksheet.write(0, 2, 'Institute')

# Initialize row number for data entry, starting from row 1 as row 0 has headers
row_num = 1

# Loop through each URL
for url in urls:
    try:
        # Fetch HTML content
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        html_content = response.text
        print(f'Successfully fetched content from: {url}')
    except requests.exceptions.RequestException as e:
        print(f'Failed to fetch HTML content for URL: {url} due to {e}')
        continue

    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract Name, Email, and Research Area directly using the IDs
    name = soup.find('h5', id='xm').get_text() if soup.find('h5', id='xm') else 'N/A'
    email = soup.find('h5', id='dzyj').get_text() if soup.find('h5', id='dzyj') else 'N/A'

    # Extract Research Area from span tags with specific style
    # research_area_spans = soup.select('div span[style="line-height: normal"]')
    # research_area = ' '.join([span.get_text() for span in research_area_spans]) if research_area_spans else 'N/A'
    research_area = "Computer Network Information Center,Chinese Academy of Science"
    # Write data to the worksheet
    worksheet.write(row_num, 0, name)
    worksheet.write(row_num, 1, email)
    worksheet.write(row_num, 2, research_area)

    # Increment row number
    row_num += 1

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339064.html
# Successfully fetched content from: http://english.cnic.cas.cn/sourcedb/People/200908/t20090817_339063.html
# Successfully fetched content from: http://english.cnic.cas.cn/sourcedb/People/201803/t20180307_339052.html
# Successfully fetched content from: http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678885.html
# Successfully fetched content from: http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678886.html
# Successfully fetched content from: http://english.cnic.cas.cn/sourcedb/People/202001/t20200116_339062.html
# Successfully fetched content from: http://english.cnic.cas.cn/sourcedb/People/202407/t20240731_678887.html
# Successfully fetched content from: http://english.cnic.cas.cn/sourcedb/People/201803/t20180307_339061.html
# Successfully fetched content from: http://english.cnic.cas.cn/sourcedb/People/200909/t20090917_339059.html
# ...

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter

# Define URLs as an array (list)
urls = [
    "http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565195.html",
    "http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565235.html",
    "http://english.cigit.cas.cn/sourcedb/ywrc/202401/t20240117_655896.html",
    "http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565219.html",
    "http://english.cigit.cas.cn/sourcedb/ywrc/202401/t20240117_655890.html",
    "http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565199.html",
    "http://english.cigit.cas.cn/sourcedb/ywrc/202401/t20240117_655891.html",
    "http://english.cigit.cas.cn/sourcedb/ywrc/202401/t20240117_655939.html",
    "http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565215.html",
    "http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565222.html",
    "http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565205.html",
    "http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565227.html",
]

# Create an Excel workbook and worksheet using xlsxwriter
excel_file_path = 'extracted_data.xlsx'
workbook = xlsxwriter.Workbook(excel_file_path)
worksheet = workbook.add_worksheet()

# Write column headers
worksheet.write(0, 0, 'Name')
worksheet.write(0, 1, 'Email')
worksheet.write(0, 2, 'Institute')

# Initialize row number for data entry, starting from row 1 as row 0 has headers
row_num = 1

# Loop through each URL
for url in urls:
    try:
        # Fetch HTML content
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        html_content = response.text
        print(f'Successfully fetched content from: {url}')
    except requests.exceptions.RequestException as e:
        print(f'Failed to fetch HTML content for URL: {url} due to {e}')
        continue

    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract Name from <div class="name">
    name = soup.find('div', class_='name').get_text(strip=True) if soup.find('div', class_='name') else 'N/A'

    # Extract Email by checking <li> for <label>E-Mail：</label> and extracting from <span>
    email = 'N/A'
    for li in soup.find_all('li'):
        label = li.find('label')
        if label and 'E-Mail: ' in label.get_text():
            email_span = li.find('span')
            if email_span:
                email = email_span.get_text(strip=True)
                break

    # Use a fixed Institute name, as given
    research_area = "Chongqing Institute of Green and Intelligent Technology, Chinese Academy of Sciences"

    # Write data to the worksheet
    worksheet.write(row_num, 0, name)
    worksheet.write(row_num, 1, email)
    worksheet.write(row_num, 2, research_area)

    # Increment row number
    row_num += 1

# Close the workbook
workbook.close()

print(f'Scraped content saved to {excel_file_path}')
# Out:
# Successfully fetched content from: http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565195.html
# Successfully fetched content from: http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565235.html
# Successfully fetched content from: http://english.cigit.cas.cn/sourcedb/ywrc/202401/t20240117_655896.html
# Successfully fetched content from: http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565219.html
# Successfully fetched content from: http://english.cigit.cas.cn/sourcedb/ywrc/202401/t20240117_655890.html
# Successfully fetched content from: http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565199.html
# Successfully fetched content from: http://english.cigit.cas.cn/sourcedb/ywrc/202401/t20240117_655891.html
# Successfully fetched content from: http://english.cigit.cas.cn/sourcedb/ywrc/202401/t20240117_655939.html
# Successfully fetched content from: http://english.cigit.cas.cn/sourcedb/ywrc/202311/t20231105_565215.html
# ...
